# %%
#set
# inbuild python data structure 
# wont allow duplicates
# un orderd
# no indexes 
# mutable
# fast searching
# {}
# hashing

# %%
s1=set()
print(type(s1))
s2={}
print(type(s2))
# Out:
# <class 'set'>
# <class 'dict'>

# %%
s1={10,20,30,10,20,30}
print(s1)
s2=set([10,20,30,10,20,30]) #convert list to set
print(s2)
s3=set({10,20,30,10,20,30})
print(s3)
# Out:
# {10, 20, 30}
# {10, 20, 30}
# {10, 20, 30}

# %%
s1={1,2}
s1.add(3)
s1.update([4,5])
print(s1)
# Out:
# {1, 2, 3, 4, 5}

# %%
s1={10,20,30,40,50}
s1.remove(10)
print(s1)
# Out:
# {50, 20, 40, 30}

# %%
s1={10,20,30,40,50}
s1.discard(10)
print(s1)
# Out:
# {50, 20, 40, 30}

# %%
s1={10,20,30,40,50}
s1.pop()
print(s1)
# Out:
# {20, 40, 10, 30}

# %%
s1={10,20,30,40,50}
s1.clear()
print(s1)
# Out:
# set()

# %%
s1={10,20,30}
s2={30,40,50}
print(s1.union(s2))
# Out:
# {50, 20, 40, 10, 30}

# %%
s1={10,20,30}
s2={30,40,50}
print(s1.union(s2))

# %%
s1={10,20,30}
s2={30,40,50}
print(s1.intersection(s2))
# Out:
# {30}

# %%
s1={10,20,30}
s2={30,40,50}
print(s1.difference(s2))
print(s2.difference(s1))
# Out:
# {10, 20}
# {40, 50}

# %%
s1={10,20,30}
s2={30,40,50}
print(s1.symmetric_difference(s2))
print(s1.symmetric_difference(s2))
# Out:
# {40, 10, 50, 20}
# {40, 10, 50, 20}

# %%
s1={10,20,30,40,50}
print(30 in s1)
print(300 not in s1)
# Out:
# True
# True

# %%
s1={10,20,30}
s2=tuple(s1)
print(s2)
# Out:
# (10, 20, 30)
