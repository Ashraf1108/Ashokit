# %%
#Tuples 
# ordered
# Immutable 
# Allows dupliccate 
# hetrogenious 
# indexing, slicing 
# ()
# faster comapred to lists

# %%
t1=()
print(t1)
# Out:
# ()

# %%
t2=(10,20,30,40,50) #homogenious elements
print(t2)
# Out:
# (10, 20, 30, 40, 50)

# %%
t3=(10,10.1,"hello",True) #hetrogenious elements
print(t3)
# Out:
# (10, 10.1, 'hello', True)

# %%
t4 = tuple((10,20,30,40)) # tuple contructor 
print(t4)
# Out:
# (10, 20, 30, 40)

# %%
print(type(t2))
# Out:
# <class 'tuple'>

# %%
t5=(10)
print(type(t5))
# Out:
# <class 'int'>

# %%
t6=(10,)
print(type(t6))
# Out:
# <class 'tuple'>

# %%
t1 = (10,20,30,40,50)
print(t1[0])
print(t1[-5])
print(t1[0])
print(t1[0:3])
print(t1[:2])
print(t1[2:])
print(t1[0:4:2])
print(t1[::-2])
# Out:
# 10
# 10
# 10
# (10, 20, 30)
# (10, 20)
# (30, 40, 50)
# (10, 30)
# (50, 30, 10)

# %%
# t1 = (10,20,30,40,50)
# t1[0]=100
# Out:
# -------------------------------------------------------
# TypeError             Traceback (most recent call last)
# Cell In[14], line 2
#       1 t1 = (10,20,30,40,50)
# ----> 2 t1[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = (10,20,30,40,50)
list1= list(t1)
list1[0]=100
t1=tuple(list1)
print(t1)
# Out:
# (100, 20, 30, 40, 50)
